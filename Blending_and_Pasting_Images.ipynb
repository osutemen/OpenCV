# %% [markdown]
# # Blending and Pasting Images

# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load two images
img1 = cv2.imread('images/person_sun.jpg')
img2 = cv2.imread('images/cv.png')

# %%
print(f' shape of image 1 {img1.shape} \n shape of image 2 {img2.shape}')
# Out:
#  shape of image 1 (440, 660, 3)
#  shape of image 2 (1024, 831, 3)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
# Convert to gray 
img_gray =cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray, cmap='gray')

# %%
mask_inv = cv2.bitwise_not(img_gray)
